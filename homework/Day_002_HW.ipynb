# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = './data/'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: ./data/application_train.csv

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
print("The column number of the data is %.d." % len(app_train.columns))
print("The row number of the data is %.d." % app_train.size)
# Out:
# The column number of the data is 122.
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)
# The row number of the data is 1047980.

# %% [markdown]
# #### 列出所有欄位

# %%
app_train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %% [markdown]
# #### 截取部分資料

# %%
app_train.tail(10)
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 8580      109990       0         Cash loans           F            N
# 8581      109991       0         Cash loans           F            N
# 8582      109993       1         Cash loans           F            N
# 8583      109994       0         Cash loans           F            N
# 8584      109995       0         Cash loans           F            N
# 8585      109996       0         Cash loans           M            N
# 8586      109997       0         Cash loans           F            N
# 8587      109998       0         Cash loans           F            N
# 8588      109999       0         Cash loans           M            Y
# 8589      110000       0         Cash loans           F            N
#
#      FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 8580               Y             0          270000.0    221031.0      17487.0
# 8581               Y             2           90000.0    119893.5      13041.0
# 8582               Y             0          126000.0    723996.0      34960.5
# 8583               Y             1           90000.0    369720.0      29340.0
# 8584               Y             0          225000.0    625356.0      18049.5
# 8585               Y             0          180000.0    101880.0      10206.0
# 8586               Y             0          157500.0    139500.0       5386.5
# 8587               Y             0           49500.0    536917.5      19413.0
# 8588               N             0          270000.0   1096020.0      46566.0
# 8589               Y             0          270000.0    364896.0      15457.5
#
#                  ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 8580             ...                             0                0
# 8581             ...                             0                0
# 8582             ...                             0                0
# 8583             ...                             0                0
# 8584             ...                             0                0
# 8585             ...                             0                0
# 8586             ...                             0                0
# 8587             ...                             0                0
# 8588             ...                             0                0
# 8589             ...                             0                0
#
#      FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# 8580                0                0                        0.0
# 8581                0                0                        0.0
# 8582                0                0                        0.0
# 8583                0                0                        0.0
# 8584                0                0                        0.0
# 8585                0                0                        0.0
# 8586                0                0                        0.0
# 8587                0                0                        0.0
# 8588                0                0                        0.0
# 8589                0                0                        0.0
#
#      AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 8580                       0.0                         0.0
# 8581                       0.0                         0.0
# 8582                       0.0                         0.0
# 8583                       0.0                         0.0
# 8584                       0.0                         0.0
# 8585                       0.0                         0.0
# 8586                       0.0                         0.0
# 8587                       0.0                         0.0
# 8588                       0.0                         0.0
# 8589                       0.0                         0.0
#
#       AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 8580                        0.0                        0.0
# 8581                        0.0                        1.0
# 8582                        0.0                        0.0
# 8583                        0.0                        0.0
# 8584                        0.0                        0.0
# 8585                        0.0                        0.0
# 8586                        1.0                        0.0
# 8587                        0.0                        0.0
# 8588                        0.0                        1.0
# 8589                        0.0                        0.0
#
#       AMT_REQ_CREDIT_BUREAU_YEAR
# 8580                         2.0
# 8581                         0.0
# 8582                         2.0
# 8583                         4.0
# 8584                         5.0
# 8585                         4.0
# 8586                         7.0
# 8587                         0.0
# 8588                         2.0
# 8589                         3.0
#
# [10 rows x 122 columns]

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子
